# %% [markdown]
# # Chapter 2
# #### Nicetak

# %%
import datetime; datetime.datetime.now().strftime('%B %-d, %Y')
# Out:
# 'April 7, 2022'

# %%
 # %load_ext autoreload
 # %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from taxi import Taxi
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.1 Q-learning
# >Implement Q-learning for Taxi, including the procedure to derive the best policy for the Q-table.
# >- Go to Sect. 2.2.4.5 and implement it.
# >- Print the Q-table, to see the values on the squares. -You could print a live policy as the search progresses.
# >- Try different values for 𝜖, the exploration rate. Does it learn faster? Does it keep finding the optimal solution?
# >- Try different values for 𝛼, the learning rate. Is it faster?

# %%
taxi = Taxi()
taxi.train(verbose = True)
# Out:
# Episode 0 Total Reward: -533
# Episode 100 Total Reward: -184
# Episode 200 Total Reward: -145
# Episode 300 Total Reward: -104
# Episode 400 Total Reward: -53
# Episode 500 Total Reward: -2
# Episode 600 Total Reward: -18
# Episode 700 Total Reward: -75
# Episode 800 Total Reward: -23
# Episode 900 Total Reward: 2

# %%
epsilons = [0.001, 0.01, 0.1, 0.2, 0.5]
alphas = [0.01, 0.1, 0.2, 0.5, 0.99]

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

for (epsilon, alpha) in zip(epsilons, alphas):
    
    taxi = Taxi()
    taxi.train(epsilon=epsilon)
    xs = range(0, taxi.n_episode, 100)
    ys = taxi.log_reward[0::100]
    ax1.plot(xs, ys, label = f"ε = {epsilon}")

    taxi = Taxi()
    taxi.train(alpha=alpha)
    xs = range(0, taxi.n_episode, 100)
    ys = taxi.log_reward[0::100]
    ax2.plot(xs, ys, label = f"α = {alpha}")

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# ## 2.2 SARSA
# >Implement SARSA, the code is in Listing 2.7.
# >- Compare your results to Q-learning, can you see how SARSA chooses different paths?
# >- Try different 𝜖 and 𝛼.

# %%
taxi = Taxi()
taxi.train(method = "SARSA", verbose=True)
# Out:
# Episode 0 Total Reward: -758
# Episode 100 Total Reward: -223
# Episode 200 Total Reward: -151
# Episode 300 Total Reward: -84
# Episode 400 Total Reward: -14
# Episode 500 Total Reward: -5
# Episode 600 Total Reward: -12
# Episode 700 Total Reward: -272
# Episode 800 Total Reward: 6
# Episode 900 Total Reward: 8

# %%
epsilons = [0.001, 0.01, 0.1, 0.2, 0.5]
alphas = [0.01, 0.1, 0.2, 0.5, 0.99]

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

for (epsilon, alpha) in zip(epsilons, alphas):
    
    taxi = Taxi()
    taxi.train(method = "SARSA", epsilon=epsilon)
    xs = range(0, taxi.n_episode, 100)
    ys = taxi.log_reward[0::100]
    ax1.plot(xs, ys, label = f"ε = {epsilon}")

    taxi = Taxi()
    taxi.train(method = "SARSA", alpha=alpha)
    xs = range(0, taxi.n_episode, 100)
    ys = taxi.log_reward[0::100]
    ax2.plot(xs, ys, label = f"α = {alpha}")

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# ## 2.3 Problem Size
# >How large can problems be before converging starts taking too long?

# %% [markdown]
# ## 2.4 Cartpole
# >Run Cartpole with the greedy policy computed by value iteration.
# >- Can you make it work?
# >- Is value iteration a suitable algorithm for Cartpole? If not, why do you think it is not?

# %%
from cartpole import Cartpole

cp = Cartpole()
cp.train(method="Value", verbose=False, n_episode=1000)

# %%
#????
cp.play()
